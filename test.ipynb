# %%
import pandas as pd
import re

# %%
import glob
files = glob.glob("*.gcode")

if len(files) > 1:
    print("Error: Too many Gcode files found!")

# Create temporary file (replace with appropriate temporary file handling)
filename = files[0]
with open(filename, 'rb') as f_in, open('temp.dat', 'wb') as f_out:
    f_out.write(f_in.read())

# %%
  def parse_float(value):
    match = re.search(r"(?<=[\w-])\d+(\.\d+)?", value)
    return float(match.group()) if match else None

# %%
# Define reading options
opts = pd.read_csv(filename, sep=' ', header=None,
                names=['Raw', 'Operation', 'X', 'Y', 'Z', 'Speed'],
                dtype={'Operation': object},
                comment=';', skipinitialspace=True, na_values=[''],
                converters={'X': parse_float, 'Y': parse_float, 'Z': parse_float, 'Speed': parse_float})
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Define reading options
# ----> 2 opts = pd.read_csv(filename, sep=' ', header=None,
#       3                 names=['Raw', 'Operation', 'X', 'Y', 'Z', 'Speed'],
#       4                 dtype={'Operation': object},
#       5                 comment=';', skipinitialspace=True, na_values=[''],
#       6                 converters={'X': parse_float, 'Y': parse_float, 'Z': parse_float, 'Speed': parse_float})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:624, in _read(filepath_or_buffer, kwds)
#     621     return parser
#     623 with parser:
# --> 624     return parser.read(nrows)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1921, in TextFileReader.read(self, nrows)
#    1914 nrows = validate_integer("nrows", nrows)
#    1915 try:
#    1916     # error: "ParserBase" has no attribute "read"
#    1917     (
#    1918         index,
#    1919         columns,
#    1920         col_dict,
# -> 1921     ) = self._engine.read(  # type: ignore[attr-defined]
#    1922         nrows
#    1923     )
#    1924 except Exception:
#    1925     self.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:921, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:1045, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File parsers.pyx:2116, in pandas._libs.parsers._apply_converter()
#
# Cell In[23], line 2, in parse_float(value)
#       1 def parse_float(value):
# ----> 2   match = re.search(r"(?<=[\w-z])\d+(\.\d+)?", value)
#       3   return float(match.group()) if match else None
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\__init__.py:176, in search(pattern, string, flags)
#     173 def search(pattern, string, flags=0):
#     174     """Scan through string looking for a match to the pattern, returning
#     175     a Match object, or None if no match was found."""
# --> 176     return _compile(pattern, flags).search(string)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\_compiler.py:745, in compile(p, flags)
#     743 if isstring(p):
#     744     pattern = p
# --> 745     p = _parser.parse(p, flags)
#     746 else:
#     747     pattern = None
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\_parser.py:989, in parse(str, flags, state)
#     986 state.flags = flags
#     987 state.str = str
# --> 989 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     990 p.state.flags = fix_flags(str, p.state.flags)
#     992 if source.next is not None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\_parser.py:464, in _parse_sub(source, state, verbose, nested)
#     462 start = source.tell()
#     463 while True:
# --> 464     itemsappend(_parse(source, state, verbose, nested + 1,
#     465                        not nested and not items))
#     466     if not sourcematch("|"):
#     467         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\_parser.py:779, in _parse(source, state, verbose, nested, first)
#     777     if lookbehindgroups is None:
#     778         state.lookbehindgroups = state.groups
# --> 779 p = _parse_sub(source, state, verbose, nested + 1)
#     780 if dir < 0:
#     781     if lookbehindgroups is None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\_parser.py:464, in _parse_sub(source, state, verbose, nested)
#     462 start = source.tell()
#     463 while True:
# --> 464     itemsappend(_parse(source, state, verbose, nested + 1,
#     465                        not nested and not items))
#     466     if not sourcematch("|"):
#     467         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\_parser.py:616, in _parse(source, state, verbose, nested, first)
#     614 if code1[0] != LITERAL or code2[0] != LITERAL:
#     615     msg = "bad character range %s-%s" % (this, that)
# --> 616     raise source.error(msg, len(this) + 1 + len(that))
#     617 lo = code1[1]
#     618 hi = code2[1]
#
# error: bad character range \w-z at position 5

# %%
opts.head(20)
# Out:
#      Raw  Operation        X      Y     Z Speed
# 0     T0        NaN      NaN    NaN  None  None
# 1   M104       S250      NaN    NaN  None  None
# 2   M105        NaN      NaN    NaN  None  None
# 3   M109       S250      NaN    NaN  None  None
# 4    M82        NaN      NaN    NaN  None  None
# 5    G92         E0      NaN    NaN  None  None
# 6    G92         E0      NaN    NaN  None  None
# 7   M107        NaN      NaN    NaN  None  None
# 8     G0      F3600  102.793    NaN  None  None
# 9     G1      F1200  107.186  16.86  None  None
# 10    G1  X-105.709   16.801    NaN  None  None
# 11    G1  X-105.674   16.943    NaN  None  None
# 12    G1  X-102.965    3.004    NaN  None  None
# 13    G1  X-102.591    8.944    NaN  None  None
# 14    G1  X-104.822   20.422    NaN  None  None
# 15    G1   X-103.97   23.901    NaN  None  None
# 16    G1  X-102.092   14.236    NaN  None  None
# 17    G1  X-101.335   18.203    NaN  None  None
# 18    G1  X-103.119   27.381    NaN  None  None
# 19    G1  X-102.267   30.859    NaN  None  None

# %%
data = opts[['X', 'Y', 'Z', 'Speed']].apply(pd.to_numeric, errors='coerce')

# %%
data.head(20)
# Out:
#           X          Y          Z  Speed Operation
# 0       NaN        NaN        NaN    NaN       nan
# 1       NaN        NaN        NaN    NaN       nan
# 2       NaN        NaN        NaN    NaN       nan
# 3       NaN        NaN        NaN    NaN       nan
# 4       NaN        NaN        NaN    NaN       nan
# 5       NaN        NaN        NaN    NaN        92
# 6       NaN        NaN        NaN    NaN        92
# 7       NaN        NaN        NaN    NaN       nan
# 8   102.793    5.74100    2.25000    NaN         0
# 9   107.186   16.86000  114.51188    NaN         1
# 10   16.801  121.86374        NaN    NaN         1
# 11   16.943  122.59112        NaN    NaN         1
# 12    3.004  193.21515        NaN    NaN         1
# 13    8.944  222.81679        NaN    NaN         1
# 14   20.422  280.97206        NaN    NaN         1
# 15   23.901  298.78651        NaN    NaN         1
# 16   14.236  347.75533        NaN    NaN         1
# 17   18.203  367.84159        NaN    NaN         1
# 18   27.381  414.34357        NaN    NaN         1
# 19   30.859  432.15318        NaN    NaN         1

# %%
data['Operation'] = opts['Raw'].str.extract(r"(?<=G)(\d+)", expand=False).astype(str)

# %%
data.head(20)
# Out:
#           X          Y          Z  Speed Operation
# 0       NaN        NaN        NaN    NaN       nan
# 1       NaN        NaN        NaN    NaN       nan
# 2       NaN        NaN        NaN    NaN       nan
# 3       NaN        NaN        NaN    NaN       nan
# 4       NaN        NaN        NaN    NaN       nan
# 5       NaN        NaN        NaN    NaN        92
# 6       NaN        NaN        NaN    NaN        92
# 7       NaN        NaN        NaN    NaN       nan
# 8   102.793    5.74100    2.25000    NaN         0
# 9   107.186   16.86000  114.51188    NaN         1
# 10   16.801  121.86374        NaN    NaN         1
# 11   16.943  122.59112        NaN    NaN         1
# 12    3.004  193.21515        NaN    NaN         1
# 13    8.944  222.81679        NaN    NaN         1
# 14   20.422  280.97206        NaN    NaN         1
# 15   23.901  298.78651        NaN    NaN         1
# 16   14.236  347.75533        NaN    NaN         1
# 17   18.203  367.84159        NaN    NaN         1
# 18   27.381  414.34357        NaN    NaN         1
# 19   30.859  432.15318        NaN    NaN         1

# %%
import math
data["Operation"] = data["Operation"].apply(lambda x: 'G'+x if x != 'nan' else '')

# %%
data
# Out:
#              X           Y   Z  Speed Operation
# 0          NaN         NaN NaN    NaN
# 1          NaN         NaN NaN    NaN
# 2          NaN         NaN NaN    NaN
# 3          NaN         NaN NaN    NaN
# 4          NaN         NaN NaN    NaN
# ...        ...         ...  ..    ...       ...
# 197251  73.547  6336.19138 NaN    NaN        G1
# 197252  83.303  6406.35888 NaN    NaN        G1
# 197253  86.276  6423.85371 NaN    NaN        G1
# 197254     NaN         NaN NaN    NaN
# 197255     NaN         NaN NaN    NaN
#
# [197256 rows x 5 columns]

# %%
data = data.loc[(data['Operation'] != 'G0') & (data['Operation'] != 'G92') & (data['Operation'] != '')]

# %%
data
# Out:
#               X           Y          Z  Speed Operation
# 9       107.186    16.86000  114.51188    NaN        G1
# 10       16.801   121.86374        NaN    NaN        G1
# 11       16.943   122.59112        NaN    NaN        G1
# 12        3.004   193.21515        NaN    NaN        G1
# 13        8.944   222.81679        NaN    NaN        G1
# ...         ...         ...        ...    ...       ...
# 197249   53.923  6214.58477        NaN    NaN        G1
# 197250   64.147  6275.38619        NaN    NaN        G1
# 197251   73.547  6336.19138        NaN    NaN        G1
# 197252   83.303  6406.35888        NaN    NaN        G1
# 197253   86.276  6423.85371        NaN    NaN        G1
#
# [193820 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193820 entries, 9 to 197253
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   X          193820 non-null  float64
#  1   Y          193820 non-null  float64
#  2   Z          2706 non-null    float64
#  3   Speed      0 non-null       float64
#  4   Operation  193820 non-null  object
# dtypes: float64(4), object(1)
# memory usage: 8.9+ MB

# %%
data = data.fillna(method='ffill')
# Out:
# C:\Users\alvaro\AppData\Local\Temp\ipykernel_18400\917065080.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method='ffill')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193820 entries, 9 to 197253
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   X          193820 non-null  float64
#  1   Y          193820 non-null  float64
#  2   Z          193820 non-null  float64
#  3   Speed      0 non-null       float64
#  4   Operation  193820 non-null  object
# dtypes: float64(4), object(1)
# memory usage: 8.9+ MB

# %%
data['Speed'] = data['Speed'] / 60 / 1000

# %%
data["Speed"].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Speed, dtype: float64

# %%
data
# Out:
#               X           Y           Z  Speed Operation
# 9       107.186    16.86000   114.51188    NaN        G1
# 10       16.801   121.86374   114.51188    NaN        G1
# 11       16.943   122.59112   114.51188    NaN        G1
# 12        3.004   193.21515   114.51188    NaN        G1
# 13        8.944   222.81679   114.51188    NaN        G1
# ...         ...         ...         ...    ...       ...
# 197249   53.923  6214.58477  5752.51178    NaN        G1
# 197250   64.147  6275.38619  5752.51178    NaN        G1
# 197251   73.547  6336.19138  5752.51178    NaN        G1
# 197252   83.303  6406.35888  5752.51178    NaN        G1
# 197253   86.276  6423.85371  5752.51178    NaN        G1
#
# [193820 rows x 5 columns]
